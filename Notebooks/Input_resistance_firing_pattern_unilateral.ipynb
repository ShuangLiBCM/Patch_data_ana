# %%
import numpy as np
import pandas as pd
import scipy.io as sio
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pdb
from Patch_ana import patch_pip
import seaborn as sns
plt.style.use('classic')
from matplotlib.backends.backend_pdf import PdfPages

% matplotlib inline
# %load_ext autoreload
% autoreload

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/data/good data storage.csv')

# %%
df.head()
# Out:
#     File name  Age  Pip number  E-I  Reci  Artifact  IS100  \
# 0  2016072704   27           3    0     0         0      1
# 1  2017021501   30           3    0     0         0      2
# 2  2016091403   30           2    0     0         0      1
# 3  2017062202   24           1    0     0         0      1
# 4  2016072902   29           1    0     1         0      0
#
#   Trial number before Trial number after  Protocol  Elimi  \
# 0         26,27,28,29              34,35         1      0
# 1               12,13              16,17         1      0
# 2               14,15                 18         1      1
# 3            30,31,32                 35         1      0
# 4                  43     45,46,47,48,49         1      0
#
#                   Notes         Ptl_note
# 0                   NaN  50Hz IE preonly
# 1                   NaN  50Hz IE preonly
# 2                   NaN  50Hz IE preonly
# 3  No change, good data  50Hz IE preonly
# 4                   NaN  50Hz IE preonly

# %%
df[(df['Reci']==0)&(df['E-I']==1)]
# Out:
#       File name  Age  Pip number  E-I  Reci  Artifact  IS100  \
# 9    2016081002   27           1    1     0         0      0
# 10   2016081703   26           2    1     0         0      1
# 11   2016081002   28           1    1     0         0      0
# 13   2016101201   30           2    1     0         0      2
# 19   2017053101   34           2    1     0         1      1
# 20   2017051501   32           1    1     0         0      1
# 30   2017032401   27           2    1     0         0      2
# 31   2017032803   31           1    1     0         0      2
# 32   2017062304   25           1    1     0         0      1
# 33   2017062701   23           1    1     0         0      1
# 34   2017060803   31           1    1     0         0      1
# 44   2017050901   25           2    1     0         0      1
# 52   2016103101   30           1    1     0         0      2
# 54   2017050901   25           2    1     0         0      1
# 55   2017052203   33           2    1     0         0      1
# 57   2016102101   26           2    1     0         0      2
# 59   2016102703   27           2    1     0         1      2
# 71   2017060502   27           1    1     0         1      1
# 86   2017041702   26           2    1     0         0      2
# 87   2017042501   32           1    1     0         0      2
# 88   2017042601   35           2    1     0         0      2
# 89   2017071401   31           2    1     0         0      1
# 97   2017042702   35           3    1     0         0      2
# 119  2017072802   22           1    1     0         0      1
# 162  2018012801   29           2    1     0         0      1
#
#     Trial number before          Trial number after  Protocol  Elimi  \
# 9                     1                       4,5,6         2      0
# 10          14,15,16,17                 20,21,22,23         2      0
# 11                    1                   4,5,6,7,8         2      0
# 13                 9,10                 12,13,14,15         2      4
# 19                  5,6                         8,9         2     18
# 20                    7                        9,10         2      0
# 30                5,6,7                        9,10         4     13
# 31                    8                 10,12,13,14         4      0
# 32          13,14,15,16             18, 19,20,21,22         4      0
# 33                   28                       30,31         4      0
# 34                13,14                          16         4      0
# 44                   12                          15         5     12
# 52                   22  25,26,27,28,29,30,31,32,33         6     15
# 54                   12                          15         6     15
# 55                  8,9                          12         6     16
# 57          31,32,33,34                       36,37         6      0
# 59             37,38,39                          41         6      0
# 71                    6                           8         9      7
# 86                  5,6                           8        11      0
# 87                21,22              24,25,26,27,28        11     14
# 88                13,14                          16        11      8
# 89          17,18,19,20                 23,24,25,26        11      0
# 97                   29                 31,32,33,35         0      0
# 119                   6                           6        15      0
# 162            27,28,29        31,32,33,34,35,36,37        21      0
#
#                                    Notes              Ptl_note
# 9                                    NaN       50Hz EI preonly
# 10                                   NaN       50Hz EI preonly
# 11                           Reduced PPR       50Hz EI preonly
# 13                           Reduced PPR       50Hz EI preonly
# 19                                   NaN       50Hz EI preonly
# 20                                   NaN       50Hz EI preonly
# 30                            Strong LTD      50Hz EI postonly
# 31             Weak LTD,no change on Rin      50Hz EI postonly
# 32   Strong LTD, careful analysis needed      50Hz EI postonly
# 33                            Strong LTD      50Hz EI postonly
# 34                            Strong LTD      50Hz EI postonly
# 44                                   NaN     50Hz IE high freq
# 52                                   NaN     50Hz EI high freq
# 54                                   NaN     50Hz EI high freq
# 55                                   NaN     50Hz EI high freq
# 57                                           50Hz EI high freq
# 59                                   NaN     50Hz EI high freq
# 71                     Big amp, weak lTD        EI_antihebbian
# 86                                   LTD           EI_low high
# 87                                   LTD           EI_low high
# 88                                   LTD           EI_low high
# 89                                   LTD           EI_low high
# 97                              Weak LTD                   NaN
# 119            No rundown for 40 minutes                No ptl
# 162                            No change  E_I_2Hz_Associ_AM251

# %%
trial = '/data/test2017051503'
trial = sio.loadmat(trial)

# %%
data = trial['test'][0]

# %%
test_pip = 3
index = 5
trace_e = data[index][0][0][0][0][test_pip-1][0][0][1]

# %%
trace_e.shape

# %%
plt.plot(trace_e.transpose()[:,5:], 'b')
with PdfPages('/data/Figure0_3.pdf') as pdf:
    pdf.savefig()

# %%
test_pip = 1
index = 4
trace_i = data[index][0][0][0][0][test_pip-1][0][0][1]

# %%
trace_i.shape
# Out:
# (12, 20000)

# %%
plt.plot(trace_i.transpose()[:,3:-1], 'b')
with PdfPages('/data/Figure0_4.pdf') as pdf:
    pdf.savefig()

# %%
trial = '/data/test2017062804'
trial = sio.loadmat(trial)

# %%
data = trial['test'][0]

# %%
pre_pip = 1
post_pip = 2
index = 0
trace_pre = data[index][0][0][0][0][pre_pip-1][0][0][1].transpose()
trace_post = data[index][0][0][0][0][post_pip-1][0][0][1].transpose()

fig, ax = plt.subplots(2,1)
ax[0].plot(trace_pre)
ax[1].plot(trace_post)
ax[1].set_ylim([-0.07, -0.05])
with PdfPages('/data/Figure0_5.pdf') as pdf:
    pdf.savefig()

# %%
pre_pip = 2
post_pip = 1
index = 1
trace_pre = data[index][0][0][0][0][pre_pip-1][0][0][1].transpose()
trace_post = data[index][0][0][0][0][post_pip-1][0][0][1].transpose()

fig, ax = plt.subplots(2,1)
ax[0].plot(trace_pre)
ax[1].plot(trace_post)
ax[1].set_ylim([-0.075, -0.055])
with PdfPages('/data/Figure0_6.pdf') as pdf:
    pdf.savefig()

# %%
# Visualize paired pulse ratio
trial = '/data/test2017062804'
trial = sio.loadmat(trial)

# %%
data = trial['test'][0]

# %%
pre_pip = 1
post_pip = 2
index = 4
trace_pre = data[index][0][0][0][0][pre_pip-1][0][0][1].transpose()
trace_post = data[index][0][0][0][0][post_pip-1][0][0][1].transpose()

fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(np.mean(trace_pre, axis=1))
ax[1].plot(np.mean(trace_post, axis=1))
ax[0].set_xlim([10000, 20000])
ax[1].set_ylim([-2e-10, 1e-10])

with PdfPages('/data/Figure0_6.pdf') as pdf:
    pdf.savefig()

# %%
df[(df['E-I']==0)&(df['IS100']==1)].head()
# Out:
#     File name  Age  Pip number  E-I  Reci  Artifact  IS100  \
# 0  2016072704   27           3    0     0         0      1
# 2  2016091403   30           2    0     0         0      1
# 3  2017062202   24           1    0     0         0      1
# 6  2016092601   26           1    0     1         1      1
# 7  2016091502   25           2    0     1         0      1
#
#   Trial number before Trial number after  Protocol  Elimi  \
# 0         26,27,28,29              34,35         1      0
# 2               14,15                 18         1      1
# 3            30,31,32                 35         1      0
# 6               13,14        16,17,18,19         1      6
# 7                   3                6,7         1      3
#
#                   Notes         Ptl_note
# 0                   NaN  50Hz IE preonly
# 2                   NaN  50Hz IE preonly
# 3  No change, good data  50Hz IE preonly
# 6                   NaN  50Hz IE preonly
# 7                   NaN  50Hz IE preonly

# %%
# Visualize paired pulse ratio
trial = '/data/test2016091403'
trial = sio.loadmat(trial)
data = trial['test'][0]
pre_pip = 1
post_pip = 2
index = 17
trace_pre = data[index][0][0][0][0][pre_pip-1][0][0][1].transpose()
trace_post = data[index][0][0][0][0][post_pip-1][0][0][1].transpose()

fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(np.mean(trace_pre, axis=1))
ax[1].plot(np.mean(trace_post, axis=1))
ax[0].set_xlim([10000, 20000])
ax[1].set_ylim([-2e-10, 1e-10])

with PdfPages('/data/Figure0_7.pdf') as pdf:
    pdf.savefig()
